# %%
# !pip uninstall keras -y
# !pip uninstall tensorflow -y
# !pip install tensorflow==2.3.0
# !pip install keras

# !pip uninstall tensorflow -y
# !pip install tensorflow==2.2.0

# %%
# !nvidia-smi #show GPU if one is enabled
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install git+https://github.com/mr7495/RetinaNet_Motile_objects_Detection --upgrade
# Out:
# Collecting git+https://github.com/mr7495/RetinaNet_Motile_objects_Detection
#   Cloning https://github.com/mr7495/RetinaNet_Motile_objects_Detection to c:\users\ngao\appdata\local\temp\pip-req-build-c85oxpfw
# Requirement already satisfied, skipping upgrade: keras==2.3.1 in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (2.3.1)
# Requirement already satisfied, skipping upgrade: keras-resnet==0.1.0 in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (0.1.0)
# Requirement already satisfied, skipping upgrade: six in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: cython in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (0.29.15)
# Requirement already satisfied, skipping upgrade: Pillow in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (7.0.0)
# Requirement already satisfied, skipping upgrade: opencv-python in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (4.5.5.62)
# Requirement already satisfied, skipping upgrade: progressbar2 in c:\users\ngao\anaconda3\lib\site-packages (from keras-retinanet==0.5.2) (4.0.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in c:\users\ngao\anaconda3\lib\site-packages (from keras==2.3.1->keras-retinanet==0.5.2) (1.18.5)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in c:\users\ngao\anaconda3\lib\site-packages (from keras==2.3.1->keras-retinanet==0.5.2) (1.1.2)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in c:\users\ngao\anaconda3\lib\site-packages (from keras==2.3.1->keras-retinanet==0.5.2) (1.0.8)
# Requirement already satisfied, skipping upgrade: h5py in c:\users\ngao\anaconda3\lib\site-packages (from keras==2.3.1->keras-retinanet==0.5.2) (2.10.0)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\ngao\anaconda3\lib\site-packages (from keras==2.3.1->keras-retinanet==0.5.2) (5.3)
# Requirement already satisfied, skipping upgrade: python-utils>=3.0.0 in c:\users\ngao\anaconda3\lib\site-packages (from progressbar2->keras-retinanet==0.5.2) (3.1.0)
# Building wheels for collected packages: keras-retinanet
#   Building wheel for keras-retinanet (setup.py): started
#   Building wheel for keras-retinanet (setup.py): finished with status 'done'
#   Created wheel for keras-retinanet: filename=keras_retinanet-0.5.2-cp37-cp37m-win_amd64.whl size=113762 sha256=026d13a25cec31f2b8f9bdbfa5dba0c6f30951496ec6cb4a3cd441c4bcc239b3
#   Stored in directory: C:\Users\NGAO\AppData\Local\Temp\pip-ephem-wheel-cache-yqvsdqa4\wheels\6d\05\e5\540c102ac65488d7a0c8f2a2e3ac39b2615dc054f8dfd3f2a1
# Successfully built keras-retinanet
# Installing collected packages: keras-retinanet
#   Attempting uninstall: keras-retinanet
#     Found existing installation: keras-retinanet 0.5.2
#     Uninstalling keras-retinanet-0.5.2:
#       Successfully uninstalled keras-retinanet-0.5.2
# Successfully installed keras-retinanet-0.5.2
#   Running command git clone -q https://github.com/mr7495/RetinaNet_Motile_objects_Detection 'C:\Users\NGAO\AppData\Local\Temp\pip-req-build-c85oxpfw'

# %%
# !git clone https://github.com/mr7495/RetinaNet_Motile_objects_Detection
# Out:
# Cloning into 'RetinaNet_Motile_objects_Detection'...

# %%
cd RetinaNet_Motile_objects_Detection
# Out:
# C:\Users\NGAO\Desktop\school\AI\RetinaNet_Motile_objects_Detection

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# skipping 'keras_retinanet/utils\compute_overlap.c' Cython extension (up-to-date)
# copying build\lib.win-amd64-3.7\keras_retinanet\utils\compute_overlap.cp37-win_amd64.pyd -> keras_retinanet\utils
# C:\Users\NGAO\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'modifier'
#   warnings.warn(msg)
# C:\Users\NGAO\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'modifier_email'
#   warnings.warn(msg)

# %%
cd ..
# Out:
# C:\Users\NGAO\Desktop\school\AI

# %%
# conda install -c conda-forge google-colab
# !pip install termios
# Out:
# ERROR: Could not find a version that satisfies the requirement termios (from versions: none)
# ERROR: No matching distribution found for termios

# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras
import csv
# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
# from google.colab.patches import cv2_imshow
# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# !pip freeze
# Out:
# absl-py==1.0.0
# aiohttp==3.8.1
# aiosignal==1.2.0
# alabaster==0.7.12
# altair==4.2.0
# anaconda-client==1.7.2
# anaconda-navigator==1.9.12
# anaconda-project==0.8.3
# appdirs==1.4.4
# argh==0.26.2
# asn1crypto==1.3.0
# astor==0.8.1
# astroid==2.3.3
# astropy==4.0
# astunparse==1.6.3
# async-timeout==4.0.2
# asynctest==0.13.0
# atomicwrites==1.3.0
# attrs==19.3.0
# audioread==2.1.9
# autopep8==1.4.4
# Babel==2.8.0
# backcall==0.1.0
# backports.functools-lru-cache==1.6.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# backports.zoneinfo==0.2.1
# base58==2.1.1
# bcrypt==3.1.7
# beautifulsoup4==4.8.2
# bitarray==1.2.1
# bkcharts==0.2
# bleach==3.1.0
# blinker==1.4
# bokeh==1.4.0
# boto==2.49.0
# Bottleneck==1.3.2
# cachetools==4.2.4
# certifi==2019.11.28
# cffi==1.14.0
# chardet==3.0.4
# charset-normalizer==2.0.12
# clang==5.0
# Click==7.0
# cloudpickle==1.3.0
# clyent==1.2.2
# colorama==0.4.3
# comtypes==1.1.7
# conda==4.12.0
# conda-build==3.18.11
# conda-package-handling==1.6.0
# conda-verify==3.4.2
# contextlib2==0.6.0.post1
# cryptography==2.8
# cycler==0.10.0
# Cython==0.29.15
# cytoolz==0.10.1
# dask==2.11.0
# decorator==4.4.1
# defusedxml==0.6.0
# diff-match-patch==20181111
# distributed==2.11.0
# docutils==0.16
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastcache==1.1.0
# filelock==3.0.12
# flake8==3.7.9
# Flask==1.1.1
# flatbuffers==1.12
# frozenlist==1.2.0
# fsspec==0.6.2
# future==0.18.2
# gast==0.3.3
# gevent==1.4.0
# gitdb==4.0.9
# GitPython==3.1.24
# glob2==0.7
# google-auth==1.35.0
# google-auth-oauthlib==0.4.6
# google-colab==1.0.0
# google-pasta==0.2.0
# greenlet==0.4.15
# grpcio==1.40.0
# h5py==2.10.0
# HeapDict==1.0.1
# html5lib==1.0.1
# hypothesis==5.5.4
# idna==2.8
# imageio==2.6.1
# imagesize==1.2.0
# importlib-metadata==4.11.3
# intervaltree==3.0.2
# ipykernel==5.1.4
# ipython==7.12.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.14.1
# Jinja2==2.11.1
# joblib==0.14.1
# json5==0.9.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==6.1.0
# jupyter-core==4.6.1
# jupyterlab==1.2.6
# jupyterlab-server==1.0.6
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.2
# keras-resnet==0.1.0
# keras-retinanet==0.5.2
# keyring==21.1.0
# kiwisolver==1.1.0
# lazy-object-proxy==1.4.3
# libarchive-c==2.8
# libclang==12.0.0
# librosa==0.8.1
# llvmlite==0.31.0
# locket==0.2.0
# lxml==4.5.0
# Markdown==3.3.6
# MarkupSafe==1.1.1
# matplotlib==3.1.3
# mccabe==0.6.1
# menuinst==1.4.16
# mistune==0.8.4
# mkl-fft==1.0.15
# mkl-random==1.1.0
# mkl-service==2.3.0
# mock==4.0.1
# more-itertools==8.2.0
# mpmath==1.1.0
# msgpack==0.6.1
# multidict==5.2.0
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.6.1
# nbformat==5.0.4
# networkx==2.4
# nltk==3.4.5
# nose==1.3.7
# notebook==6.0.3
# numba==0.48.0
# numexpr==2.7.1
# numpy==1.18.5
# numpydoc==0.9.2
# oauthlib==3.1.1
# olefile==0.46
# opencv-python==4.5.5.62
# openpyxl==3.0.3
# opt-einsum==3.3.0
# packaging==20.1
# pandas==1.0.1
# pandocfilters==1.4.2
# paramiko==2.7.1
# parso==0.5.2
# partd==1.1.0
# path==13.1.0
# pathlib2==2.3.5
# pathtools==0.1.2
# patsy==0.5.1
# pep8==1.7.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.0.0
# pkginfo==1.5.0.1
# pluggy==0.13.1
# ply==3.11
# pooch==1.5.2
# portpicker==1.5.0
# progressbar2==4.0.0
# prometheus-client==0.7.1
# prompt-toolkit==3.0.3
# protobuf==3.19.1
# psutil==5.6.7
# py==1.8.1
# pyarrow==6.0.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.5
# pydeck==0.7.1
# pydocstyle==4.0.1
# pyflakes==2.1.1
# Pygments==2.5.2
# pylint==2.4.4
# Pympler==1.0.1
# PyNaCl==1.3.0
# pyodbc===4.0.0-unsupported
# pyOpenSSL==19.1.0
# pyparsing==2.4.6
# PyQt5==5.15.6
# PyQt5-Qt5==5.15.2
# PyQt5-sip==12.9.1
# pyreadline==2.1
# pyrsistent==0.15.7
# PySocks==1.7.1
# pytest==5.3.5
# pytest-arraydiff==0.3
# pytest-astropy==0.8.0
# pytest-astropy-header==0.1.2
# pytest-doctestplus==0.5.0
# pytest-openfiles==0.4.0
# pytest-remotedata==0.3.2
# python-dateutil==2.8.1
# python-jsonrpc-server==0.3.4
# python-language-server==0.31.7
# python-utils==3.1.0
# pytz==2019.3
# pytz-deprecation-shim==0.1.0.post0
# PyWavelets==1.1.1
# pywin32==227
# pywin32-ctypes==0.2.0
# pywinpty==0.5.7
# PyYAML==5.3
# pyzmq==18.1.1
# QDarkStyle==2.8
# QtAwesome==0.6.1
# qtconsole==4.6.0
# QtPy==1.9.0
# requests==2.22.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# rope==0.16.0
# rsa==4.8
# Rtree==0.9.3
# ruamel-yaml==0.15.87
# scikit-image==0.16.2
# scikit-learn==0.22.1
# scipy==1.4.1
# seaborn==0.10.0
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.15.0
# smmap==5.0.0
# snowballstemmer==2.0.0
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# SoundFile==0.10.3.post1
# soupsieve==1.9.5
# Sphinx==2.4.0
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.2.0
# spyder==4.0.1
# spyder-kernels==1.8.1
# SQLAlchemy==1.3.13
# statsmodels==0.11.0
# streamlit==1.3.1
# sympy==1.5.1
# tables==3.6.1
# tblib==1.6.0
# tensorboard==2.2.2
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.2.0
# tensorflow-estimator==2.2.0
# tensorflow-io-gcs-filesystem==0.23.1
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# toml==0.10.2
# toolz==0.10.0
# tornado==6.0.3
# tqdm==4.42.1
# traitlets==4.3.3
# typing-extensions==4.2.0
# tzdata==2021.5
# tzlocal==4.1
# ujson==1.35
# unicodecsv==0.14.1
# urllib3==1.25.8
# validators==0.18.2
# watchdog==0.10.2
# wcwidth==0.1.8
# webencodings==0.5.1
# webm==0.12.1
# Werkzeug==1.0.0
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt==1.11.2
# xlrd==1.2.0
# XlsxWriter==1.2.7
# xlwings==0.17.1
# xlwt==1.3.0
# xmltodict==0.12.0
# yapf==0.28.0
# yarl==1.7.2
# zict==1.0.0
# zipp==2.2.0
# WARNING: Could not generate requirement for distribution -umpy 1.18.1 (c:\users\ngao\anaconda3\lib\site-packages): Parse error at "'-umpy==1'": Expected W:(abcd...)

# %%
#Our trained RetinaNet for detecting sperms based on 3 consecutive frames is free to use on:
#https://drive.google.com/open?id=1pN3A-tWJOphRdTZ7cPhJTnTIhoiGrcWv
#Add this file to your drive and connbet you google drive to colab using:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_path = 'model/final_retinanet_sperm_detection_3frames.h5' #Path to inference model

# load retinanet model

model = models.load_model(model_path)
#print(model.summary())

# load label to names mapping for visualization purposes
labels_to_names = {0: 'Sperm'}
# Out:
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-22.627417, -11.313708,  22.627417,  11.313708],
#        [-28.50876 , -14.25438 ,  28.50876 ,  14.25438 ],
#        [-35.918785, -17.959393,  35.918785,  17.959393],
#        [-16.      , -16.      ,  16.      ,  16.      ],
#        [-20.158737, -20.158737,  20.158737,  20.158737],
#        [-25.398417, -25.398417,  25.398417,  25.398417],
#        [-11.313708, -22.627417,  11.313708,  22.627417],
#        [-14.25438 , -28.50876 ,  14.25438 ,  28.50876 ],
#        [-17.959393, -35.918785,  17.959393,  35.918785]], dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-45.254833, -22.627417,  45.254833,  22.627417],
#        [-57.01752 , -28.50876 ,  57.01752 ,  28.50876 ],
#        [-71.83757 , -35.918785,  71.83757 ,  35.918785],
#        [-32.      , -32.      ,  32.      ,  32.      ],
#        [-40.317474, -40.317474,  40.317474,  40.317474],
#        [-50.796833, -50.796833,  50.796833,  50.796833],
#        [-22.627417, -45.254833,  22.627417,  45.254833],
#        [-28.50876 , -57.01752 ,  28.50876 ,  57.01752 ],
#        [-35.918785, -71.83757 ,  35.918785,  71.83757 ]], dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[ -90.50967 ,  -45.254833,   90.50967 ,   45.254833],
#        [-114.03504 ,  -57.01752 ,  114.03504 ,   57.01752 ],
#        [-143.67514 ,  -71.83757 ,  143.67514 ,   71.83757 ],
#        [ -64.      ,  -64.      ,   64.      ,   64.      ],
#        [ -80.63495 ,  -80.63495 ,   80.63495 ,   80.63495 ],
#        [-101.593666, -101.593666,  101.593666,  101.593666],
#        [ -45.254833,  -90.50967 ,   45.254833,   90.50967 ],
#        [ -57.01752 , -114.03504 ,   57.01752 ,  114.03504 ],
#        [ -71.83757 , -143.67514 ,   71.83757 ,  143.67514 ]],
#       dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-181.01933,  -90.50967,  181.01933,   90.50967],
#        [-228.07008, -114.03504,  228.07008,  114.03504],
#        [-287.35028, -143.67514,  287.35028,  143.67514],
#        [-128.     , -128.     ,  128.     ,  128.     ],
#        [-161.2699 , -161.2699 ,  161.2699 ,  161.2699 ],
#        [-203.18733, -203.18733,  203.18733,  203.18733],
#        [ -90.50967, -181.01933,   90.50967,  181.01933],
#        [-114.03504, -228.07008,  114.03504,  228.07008],
#        [-143.67514, -287.35028,  143.67514,  287.35028]], dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-362.03867, -181.01933,  362.03867,  181.01933],
#        [-456.14017, -228.07008,  456.14017,  228.07008],
#        [-574.70056, -287.35028,  574.70056,  287.35028],
#        [-256.     , -256.     ,  256.     ,  256.     ],
#        [-322.5398 , -322.5398 ,  322.5398 ,  322.5398 ],
#        [-406.37466, -406.37466,  406.37466,  406.37466],
#        [-181.01933, -362.03867,  181.01933,  362.03867],
#        [-228.07008, -456.14017,  228.07008,  456.14017],
#        [-287.35028, -574.70056,  287.35028,  574.70056]], dtype=float32)> anchors
# C:\Users\NGAO\anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# In this block you will import the address of your video
video_file="dataset/visem-dataset/10_12.03.12_minor drift_HH.avi" #path to the video file
save_path='frames' #path to the folder to save video
video_data=[]
cap = cv2.VideoCapture(video_file) #read video
count = 0
import shutil
try:
  shutil.rmtree(save_path)
except:
  pass
#create folder
try:
    os.mkdir(save_path)
except:
    pass
while cap.isOpened():
    ret,frame = cap.read()
    if ret is True:     
        count = count + 1
        cv2.imwrite("{}/{}.jpg".format(save_path,count), frame) #write frame
        video_data.append("{}/{}.jpg".format(save_path,count))  #add the data to the list
    else:
        break
cap.release()

# %%
data=[]
cnt = 0
for index,frame_data in enumerate(video_data):
  if index==0: #first frame
    img1 = read_image_bgr(frame_data) #Load Previous Frame
    img2 = read_image_bgr(frame_data) #Load Current Frame
    img3 = read_image_bgr(video_data[index+1]) #Load next Frame
  elif index== len(video_data)-1: #last frame
    img1 = read_image_bgr(video_data[index-1]) #Load Previous Frame
    img2 = read_image_bgr(frame_data) #Load Current Frame
    img3 = read_image_bgr(frame_data) #Load next Frame
  else: #other frames
    img1 = read_image_bgr(video_data[index-1]) #Load Previous Frame
    img2 = read_image_bgr(frame_data) #Load Current Frame
    img3 = read_image_bgr(video_data[index+1]) #Load next Frame

  img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY) #convert to gray scale
  img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY) #convert to gray scale
  img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY) #convert to gray scale
  image=np.concatenate((np.expand_dims(img1,axis=2),np.expand_dims(img2,axis=2),np.expand_dims(img3,axis=2)),axis=2) #concatenate 3 consecutive frames

  draw = read_image_bgr(frame_data) #the original current frame image

  # preprocess image for network
  image = preprocess_image(image)
  image, scale = resize_image(image)

  # process image
  start = time.time()
  boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
  print("processing time: ", time.time() - start)

  # correct for image scale
  boxes /= scale


  # visualize detections
  sperm_cnt = 0
  for box, score, label in zip(boxes[0], scores[0], labels[0]):
      # scores are sorted so we can break
      if score<0.5:
        break
      sperm_cnt += 1
      color = (255,0,0)
      
      b = box.astype(int)
      draw_box(draw, b, color=color)
      
      caption = "{} {:.3f}".format(labels_to_names[label], score)
      draw_caption(draw, b, caption)
      data.append([frame_data,b[0],b[1],b[2],b[3],'sperm']) #add the data to the list

  # cv2_imshow(draw)
  name = 'results/detected_'+ str(cnt) +'_sperm_'+ str(sperm_cnt) +'_.jpg'
  cv2.imwrite(name, draw)
  cnt += 1


with open('detections.csv','w',newline='') as f: #write the data to a csv file which will be used for tracking
  csvwriter=csv.writer(f)
  for row in data:
    csvwriter.writerow(row)
# Out:
# processing time:  7.844306707382202
# processing time:  3.1923792362213135
# processing time:  3.0619027614593506
# processing time:  3.331956624984741
# processing time:  3.1885576248168945
# processing time:  3.2256360054016113
# processing time:  2.582104206085205
# processing time:  2.59090256690979
# processing time:  2.6681721210479736
# processing time:  2.9318861961364746
# processing time:  2.9246842861175537
# processing time:  2.92253041267395
# processing time:  2.625138282775879
# processing time:  2.793785810470581
# processing time:  2.755722761154175
# processing time:  2.911266803741455
# processing time:  2.7161178588867188
# processing time:  2.627434730529785
# processing time:  2.7387964725494385
# processing time:  3.0165226459503174
# processing time:  2.9411778450012207
# processing time:  2.9256560802459717
# processing time:  2.715662956237793
# processing time:  2.8432235717773438
# processing time:  2.9491403102874756
# processing time:  2.9263458251953125
# processing time:  2.780273675918579
# processing time:  2.425534963607788
# processing time:  2.5232956409454346
# processing time:  2.5515401363372803
# processing time:  2.716905355453491
# processing time:  2.696323871612549
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a7d4535bb50c> in <module>
#      11     img3 = read_image_bgr(frame_data) #Load next Frame
#      12   else: #other frames
# ---> 13     img1 = read_image_bgr(video_data[index-1]) #Load Previous Frame
#      14     img2 = read_image_bgr(frame_data) #Load Current Frame
#      15     img3 = read_image_bgr(video_data[index+1]) #Load next Frame
#
# ~\anaconda3\lib\site-packages\keras_retinanet\utils\image.py in read_image_bgr(path)
#      30     """
#      31     # We deliberately don't use cv2.imread here, since it gives no feedback on errors while reading the image.
# ---> 32     image = np.asarray(Image.open(path).convert('RGB'))
#      33     return image[:, :, ::-1].copy()
#      34
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'frames/560.jpg'

# %%
img1 = read_image_bgr('RetinaNet_Motile_objects_Detection/previous_frame.jpg') #Load Previous Frame
img2 = read_image_bgr('RetinaNet_Motile_objects_Detection/Current_frame.jpg') #Load Current Frame
img3 = read_image_bgr('RetinaNet_Motile_objects_Detection/next_frame.jpg') #Load next Frame
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY) #convert to gray scale
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY) #convert to gray scale
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY) #convert to gray scale
image=np.concatenate((np.expand_dims(img1,axis=2),np.expand_dims(img2,axis=2),np.expand_dims(img3,axis=2)),axis=2) #concatenate 3 consecutive frames

print(image.shape)

draw = read_image_bgr('RetinaNet_Motile_objects_Detection/Current_frame.jpg') #the original current frame image

# preprocess image for network
image = preprocess_image(image)
image, scale = resize_image(image)

# process image
start = time.time()
boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
print("processing time: ", time.time() - start)

# correct for image scale
boxes /= scale


# visualize detections
sperm_cnt = 0
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
    if score<0.5:
      break
    sperm_cnt += 1
    color = (255,0,0)
    
    b = box.astype(int)
    draw_box(draw, b, color=color)
#     print(b)
#     x = b[0], y = b[1], w = b[2], h = b[3]
#     crop_image = draw[x:w, y:h]
#     cv2.imshow("Cropped", crop_image)
    caption = "{} {:.3f}".format(labels_to_names[label], score)
    draw_caption(draw, b, caption)
    
# cv2_imshow(draw)
# cv2.imwrite('detected.jpg',draw)
name = 'results/detected_image_sperm_'+ str(sperm_cnt) +'_.jpg'
cv2.imwrite(name, draw)
